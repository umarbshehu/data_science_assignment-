# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('birds.csv')
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# 2                 LC       64.0       79.0       2050.0       4050.0
# 3                 LC       57.3       64.0       1066.0       1567.0
# 4                 LC       64.0       81.0       1930.0       3310.0
#
#    MinWingspan  MaxWingspan
# 0         76.0         94.0
# 1         85.0         93.0
# 2        135.0        165.0
# 3        113.0        116.0
# 4        130.0        165.0

# %% [markdown]
# ### Build a line plot about bird wingspan values

# %%
wingspan = birds['MaxWingspan'] 
wingspan.plot()
# Out:
# <Axes: >

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x = birds['Name'] 
y = birds['MaxWingspan']

plt.plot(x, y)

plt.show()

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)

for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    plt.plot(x, y, 'bo')
    if birds['MaxWingspan'][i] > 500:
        plt.text(x, y * (1 - 0.05), birds['Name'][i], fontsize=12)
    
plt.show()

# %% [markdown]
# ### Filter your data

# %%
plt.title('Max Wingspan in Centimeters')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)
for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    if birds['Name'][i] not in ['Bald eagle', 'Prairie falcon']:
        plt.plot(x, y, 'bo')
plt.show()

# %% [markdown]
# ### Explore bar charts

# %%
birds.plot(x='Category',
        kind='bar',
        stacked=True,
        title='Birds of Minnesota')
# Out:
# <Axes: title={'center': 'Birds of Minnesota'}, xlabel='Category'>

# %%
category_count = birds.value_counts(birds['Category'].values, sort=True)
plt.rcParams['figure.figsize'] = [6, 12]
category_count.plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# ### Comparing data

# %%
maxlength = birds['MaxLength']
plt.barh(y=birds['Category'], width=maxlength)
plt.rcParams['figure.figsize'] = [6, 12]
plt.show()

# %%
maxlength = birds['MaxLength']
plt.barh(y=birds['Category'], width=maxlength)
plt.rcParams['figure.figsize'] = [6, 12]
plt.show()

# %%
birds.plot(kind='scatter',x='MaxLength',y='Order',figsize=(12,8))

plt.title('Max Length per Order')
plt.ylabel('Order')
plt.xlabel('Max Length')

plt.show()

# %%
birds['MaxBodyMass'].plot(kind = 'hist', bins = 10, figsize = (12,12))
plt.show()

# %%
birds['MaxBodyMass'].plot(kind = 'hist', bins = 30, figsize = (12,12))
plt.show()

# %%
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]      
filteredBirds['MaxBodyMass'].plot(kind = 'hist',bins = 40,figsize = (12,12))
plt.show()

# %%
x = filteredBirds['MaxBodyMass']
y = filteredBirds['MaxLength']

fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y)

# %%
x1 = filteredBirds.loc[filteredBirds.ConservationStatus=='EX', 'MinWingspan']
x2 = filteredBirds.loc[filteredBirds.ConservationStatus=='CR', 'MinWingspan']
x3 = filteredBirds.loc[filteredBirds.ConservationStatus=='EN', 'MinWingspan']
x4 = filteredBirds.loc[filteredBirds.ConservationStatus=='NT', 'MinWingspan']
x5 = filteredBirds.loc[filteredBirds.ConservationStatus=='VU', 'MinWingspan']
x6 = filteredBirds.loc[filteredBirds.ConservationStatus=='LC', 'MinWingspan']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='Min Wingspan')
plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(filteredBirds['MinWingspan'])
plt.show()

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'])
plt.show()

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'], bw_adjust=.2)
plt.show()

# %%
sns.kdeplot(
   data=filteredBirds, x="MaxBodyMass", hue="Order",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# /tmp/ipykernel_3069/1933666654.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# <Axes: xlabel='MaxBodyMass', ylabel='Density'>

# %%
sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# Out:
# /tmp/ipykernel_3069/49960699.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# <Axes: xlabel='MinLength', ylabel='MaxLength'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
mushrooms = pd.read_csv('mushrooms.csv')
mushrooms.head()
# Out:
#        class cap-shape cap-surface cap-color     bruises     odor  \
# 0  Poisonous    Convex      Smooth     Brown     Bruises  Pungent
# 1     Edible    Convex      Smooth    Yellow     Bruises   Almond
# 2     Edible      Bell      Smooth     White     Bruises    Anise
# 3  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 4     Edible    Convex      Smooth     Green  No Bruises      NaN
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# 3            Free        Close    Narrow      Brown  ...
# 4            Free      Crowded     Broad      Black  ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                   Smooth                  White                  White
# 1                   Smooth                  White                  White
# 2                   Smooth                  White                  White
# 3                   Smooth                  White                  White
# 4                   Smooth                  White                  White
#
#   veil-type veil-color ring-number   ring-type spore-print-color population  \
# 0   Partial      White         One     Pendant             Black  Scattered
# 1   Partial      White         One     Pendant             Brown   Numerous
# 2   Partial      White         One     Pendant             Brown   Numerous
# 3   Partial      White         One     Pendant             Black  Scattered
# 4   Partial      White         One  Evanescent             Brown   Abundant
#
#    habitat
# 0    Urban
# 1  Grasses
# 2  Meadows
# 3    Urban
# 4  Grasses
#
# [5 rows x 23 columns]

# %%
print(mushrooms.select_dtypes(["object"]).columns)
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
cols = mushrooms.select_dtypes(["object"]).columns
mushrooms[cols] = mushrooms[cols].astype('category')

# %%
edibleclass=mushrooms.groupby(['class']).count()
edibleclass
# Out:
# /tmp/ipykernel_2406/4107208836.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   edibleclass=mushrooms.groupby(['class']).count()
#            cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# class
# Edible          4208         4208       4208     4208   800             4208
# Poisonous       3916         3916       3916     3916  3796             3916
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# class                                                        ...
# Edible             4208       4208        4208         4208  ...
# Poisonous          3916       3916        3916         3916  ...
#
#            stalk-surface-below-ring  stalk-color-above-ring  \
# class
# Edible                         4208                    4208
# Poisonous                      3916                    3916
#
#            stalk-color-below-ring  veil-type  veil-color  ring-number  \
# class
# Edible                       4208       4208        4208         4208
# Poisonous                    3916       3916        3916         3880
#
#            ring-type  spore-print-color  population  habitat
# class
# Edible          4208               4208        4208     4208
# Poisonous       3880               3916        3916     3916
#
# [2 rows x 22 columns]

# %%
labels=['Edible','Poisonous']
plt.pie(edibleclass['population'],labels=labels,autopct='%.1f %%')
plt.title('Edible?')
plt.show()

# %%
habitat=mushrooms.groupby(['habitat']).count()
habitat
# Out:
# /tmp/ipykernel_2406/1821066925.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   habitat=mushrooms.groupby(['habitat']).count()
#          class  cap-shape  cap-surface  cap-color  bruises  odor  \
# habitat
# Grasses   2148       2148         2148       2148     2148  1056
# Leaves     832        832          832        832      832   576
# Meadows    292        292          292        292      292   256
# Paths     1144       1144         1144       1144     1144  1104
# Urban      368        368          368        368      368   272
# Waste      192        192          192        192      192     0
# Wood      3148       3148         3148       3148     3148  1332
#
#          gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# habitat                                                        ...
# Grasses             2148          2148       2148        2148  ...
# Leaves               832           832        832         832  ...
# Meadows              292           292        292         292  ...
# Paths               1144          1144       1144        1144  ...
# Urban                368           368        368         368  ...
# Waste                192           192        192         192  ...
# Wood                3148          3148       3148        3148  ...
#
#          stalk-surface-above-ring  stalk-surface-below-ring  \
# habitat
# Grasses                      2148                      2148
# Leaves                        832                       832
# Meadows                       292                       292
# Paths                        1144                      1144
# Urban                         368                       368
# Waste                         192                       192
# Wood                         3148                      3148
#
#          stalk-color-above-ring  stalk-color-below-ring  veil-type  \
# habitat
# Grasses                    2148                    2148       2148
# Leaves                      832                     832        832
# Meadows                     292                     292        292
# Paths                      1144                    1144       1144
# Urban                       368                     368        368
# Waste                       192                     192        192
# Wood                       3148                    3148       3148
#
#          veil-color  ring-number  ring-type  spore-print-color  population
# habitat
# Grasses        2148         2148       2148               2148        2148
# Leaves          832          832        832                832         832
# Meadows         292          292        292                292         292
# Paths          1144         1144       1144               1144        1144
# Urban           368          368        368                368         368
# Waste           192          192        192                192         192
# Wood           3148         3112       3112               3148        3148
#
# [7 rows x 22 columns]

# %%
labels=['Grasses','Leaves','Meadows','Paths','Urban','Waste','Wood']

plt.pie(habitat['class'], labels=labels,
        autopct='%1.1f%%', pctdistance=0.85)
  
center_circle = plt.Circle((0, 0), 0.40, fc='white')
fig = plt.gcf()

fig.gca().add_artist(center_circle)
  
plt.title('Mushroom Habitats')
  
plt.show()

# %%
pip install pywaffle
# Out:
# Collecting pywaffle
#   Downloading pywaffle-1.1.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting fontawesomefree (from pywaffle)
#   Downloading fontawesomefree-6.5.1-py3-none-any.whl.metadata (824 bytes)
# Requirement already satisfied: matplotlib in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from pywaffle) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (23.2)
# Requirement already satisfied: pillow>=8 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from matplotlib->pywaffle) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pywaffle) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Downloading pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# Downloading fontawesomefree-6.5.1-py3-none-any.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 2.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: fontawesomefree, pywaffle
# Successfully installed fontawesomefree-6.5.1 pywaffle-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
capcolor=mushrooms.groupby(['cap-color']).count()
capcolor
# Out:
# /tmp/ipykernel_2406/1606099690.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   capcolor=mushrooms.groupby(['cap-color']).count()
#            class  cap-shape  cap-surface  bruises  odor  gill-attachment  \
# cap-color
# Brown       2284       2284         2284     2284  1100             2284
# Buff         168        168          168      168    96              168
# Cinnamon      44         44           44       44    12               44
# Green       1856       1856         1856     1856   808             1856
# Pink         144        144          144      144    64              144
# Purple        16         16           16       16     0               16
# Red         1500       1500         1500     1500   876             1500
# White       1040       1040         1040     1040   592             1040
# Yellow      1072       1072         1072     1072  1048             1072
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# cap-color                                                    ...
# Brown              2284       2284        2284         2284  ...
# Buff                168        168         168          168  ...
# Cinnamon             44         44          44           44  ...
# Green              1856       1856        1856         1856  ...
# Pink                144        144         144          144  ...
# Purple               16         16          16           16  ...
# Red                1500       1500        1500         1500  ...
# White              1040       1040        1040         1040  ...
# Yellow             1072       1072        1072         1072  ...
#
#            stalk-surface-below-ring  stalk-color-above-ring  \
# cap-color
# Brown                          2284                    2284
# Buff                            168                     168
# Cinnamon                         44                      44
# Green                          1856                    1856
# Pink                            144                     144
# Purple                           16                      16
# Red                            1500                    1500
# White                          1040                    1040
# Yellow                         1072                    1072
#
#            stalk-color-below-ring  veil-type  veil-color  ring-number  \
# cap-color
# Brown                        2284       2284        2284         2272
# Buff                          168        168         168          168
# Cinnamon                       44         44          44           32
# Green                        1856       1856        1856         1856
# Pink                          144        144         144          144
# Purple                         16         16          16           16
# Red                          1500       1500        1500         1488
# White                        1040       1040        1040         1040
# Yellow                       1072       1072        1072         1072
#
#            ring-type  spore-print-color  population  habitat
# cap-color
# Brown           2272               2284        2284     2284
# Buff             168                168         168      168
# Cinnamon          32                 44          44       44
# Green           1856               1856        1856     1856
# Pink             144                144         144      144
# Purple            16                 16          16       16
# Red             1488               1500        1500     1500
# White           1040               1040        1040     1040
# Yellow          1072               1072        1072     1072
#
# [9 rows x 22 columns]

# %%
capcolor=mushrooms.groupby(['cap-color']).count()
capcolor
# Out:
# /tmp/ipykernel_2406/1606099690.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   capcolor=mushrooms.groupby(['cap-color']).count()
#            class  cap-shape  cap-surface  bruises  odor  gill-attachment  \
# cap-color
# Brown       2284       2284         2284     2284  1100             2284
# Buff         168        168          168      168    96              168
# Cinnamon      44         44           44       44    12               44
# Green       1856       1856         1856     1856   808             1856
# Pink         144        144          144      144    64              144
# Purple        16         16           16       16     0               16
# Red         1500       1500         1500     1500   876             1500
# White       1040       1040         1040     1040   592             1040
# Yellow      1072       1072         1072     1072  1048             1072
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# cap-color                                                    ...
# Brown              2284       2284        2284         2284  ...
# Buff                168        168         168          168  ...
# Cinnamon             44         44          44           44  ...
# Green              1856       1856        1856         1856  ...
# Pink                144        144         144          144  ...
# Purple               16         16          16           16  ...
# Red                1500       1500        1500         1500  ...
# White              1040       1040        1040         1040  ...
# Yellow             1072       1072        1072         1072  ...
#
#            stalk-surface-below-ring  stalk-color-above-ring  \
# cap-color
# Brown                          2284                    2284
# Buff                            168                     168
# Cinnamon                         44                      44
# Green                          1856                    1856
# Pink                            144                     144
# Purple                           16                      16
# Red                            1500                    1500
# White                          1040                    1040
# Yellow                         1072                    1072
#
#            stalk-color-below-ring  veil-type  veil-color  ring-number  \
# cap-color
# Brown                        2284       2284        2284         2272
# Buff                          168        168         168          168
# Cinnamon                       44         44          44           32
# Green                        1856       1856        1856         1856
# Pink                          144        144         144          144
# Purple                         16         16          16           16
# Red                          1500       1500        1500         1488
# White                        1040       1040        1040         1040
# Yellow                       1072       1072        1072         1072
#
#            ring-type  spore-print-color  population  habitat
# cap-color
# Brown           2272               2284        2284     2284
# Buff             168                168         168      168
# Cinnamon          32                 44          44       44
# Green           1856               1856        1856     1856
# Pink             144                144         144      144
# Purple            16                 16          16       16
# Red             1488               1500        1500     1500
# White           1040               1040        1040     1040
# Yellow          1072               1072        1072     1072
#
# [9 rows x 22 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
  
data ={'color': ['brown', 'buff', 'cinnamon', 'green', 'pink', 'purple', 'red', 'white', 'yellow'],
    'amount': capcolor['class']
     }
  
df = pd.DataFrame(data)
  
fig = plt.figure(
    FigureClass = Waffle,
    rows = 100,
    values = df.amount,
    labels = list(df.color),
    figsize = (30,30),
    colors=["brown", "tan", "maroon", "green", "pink", "purple", "red", "whitesmoke", "yellow"],
)
# Out:
# /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/msmaje/miniconda3/envs/deep_learning/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Waffle size 3000x3000 with 1 Axes>

# %% [markdown]
# ### Scatterplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
honey = pd.read_csv('honey.csv')
honey.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
sns.relplot(x="priceperlb", y="state", data=honey, height=15, aspect=.5)

# %%
sns.relplot(x="priceperlb", y="state", hue="year", palette="YlOrBr", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="priceperlb", y="state", size="year", data=honey, height=15, aspect=.5)

# %%
sns.relplot(x="year", y="priceperlb", kind="line", data=honey)

# %%
sns.relplot(x="year", y="totalprod", kind="line", data=honey)

# %% [markdown]
# ### Facet grids

# %%
sns.relplot(
    data=honey, 
    x="yieldpercol", y="numcol",
    col="year", 
    col_wrap=3,
    kind="line")

# %% [markdown]
# ### Dual-line Plots

# %%
fig, ax = plt.subplots(figsize=(12,6))
lineplot = sns.lineplot(x=honey['year'], y=honey['numcol'], data=honey, 
                        label = 'Number of bee colonies', legend=False)
sns.despine()
plt.ylabel('# colonies')
plt.title('Honey Production Year over Year');

ax2 = ax.twinx()
lineplot2 = sns.lineplot(x=honey['year'], y=honey['yieldpercol'], ax=ax2, color="r", 
                         label ='Yield per colony', legend=False) 
sns.despine(right=False)
plt.ylabel('colony yield')
ax.figure.legend()

# %% [markdown]
# ### Making Meaningful Visualizations
# ### Project: Build a chart to show a network using D3.js

# %%
letters = [
    {'from': 'a', 'to': 'x'},
    {'from': 'b', 'to': 'y'},
    {'from': 'c', 'to': 'z'}
]

characters = ['x', 'y', 'z']

f = 0
t = 0
links = []

for i in range(len(letters)):
    for j in range(len(characters)):
        if characters[j] == letters[i]['from']:
            f = j
        if characters[j] == letters[i]['to']:
            t = j
    links.append({'sid': f, 'tid': t})

print(links)
# Out:
# [{'sid': 0, 'tid': 0}, {'sid': 0, 'tid': 1}, {'sid': 0, 'tid': 2}]
